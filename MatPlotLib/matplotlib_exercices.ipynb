# %%
import matplotlib.pyplot as plt 
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(5,2))
x=[1,2,3,4]
y=[2,4,5,6]
'''
for current_ax in axes:
    current_ax.plot(x,y    '''
axes[0].plot(x,y)
axes[0].set_title('First Plot')

plt.tight_layout() # for overlaping problem

# %%
#fig.savefig('my_picture.jpg')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,label="X")
ax.plot(y,x,label="Y",color='purple',linewidth = 2,alpha = 0.5,linestyle="--",marker="o",markersize=20,markerfacecolor='yellow',
        markeredgecolor='green',markeredgewidth=3)
ax.legend(loc=0) #loc=0 (best location) loc =10(center)

# %%
fig = plt.figure()
